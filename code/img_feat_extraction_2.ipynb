# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
#cd /content/gdrive/My Drive/image download

# %%
#!unzip resized\ images.zip

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image, ImageOps
import glob
#from keras.applications.vgg16 import VGG16,preprocess_input
#from keras.preprocessing.image import load_img, img_to_array
from keras.models import Model

# %%
vgg16 = tf.keras.applications.VGG16()

# %%
#new_model = tf.keras.models.Sequential()

# %%
#new_model.add(vgg16.layers[0])

# %%
#new_model.build()

# %%
#new_model.summary()

# %%
vgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
features_list = [layer.output for layer in vgg16.layers]
#features_list = vgg16.layers[-1].output

# %%
type(features_list)
# Out:
# list

# %%
df = pd.read_csv("F:\\BTP\\bert test\\testvalid\\tweets_train_img_indexed.csv")

# %%
feat_extraction_model = tf.keras.Model(inputs=vgg16.input, outputs=features_list)

# %%
null_matrix = np.zeros((1,7,7,512))

# %%
null_matrix_2 = np.zeros((1,1000))

# %%
img_feat_array = [null_matrix]*24228

# %%
img_feat_array_last_layer =  [null_matrix_2]*24228

# %%
type(img_feat_array[1])
# Out:
# numpy.ndarray

# %%
i=0
for i in range(0,4165):
    #filename = filename[32:]
    #img = Image.open('F:\\BTP\\bert test\\resized images\\'+filename)
    img = Image.open('F:\\BTP\\bert test\\testvalid\\train_resized\\'+df['imgname'][i])
    #img = img.resize((224,224))
    #print(img.width,img.height)
    img = np.array(img)
    #filename = filename[32:]
    #print(filename)
    img = img.reshape(1,224,224,3)
    #j=int(filename[:-17])
    j = df['index'][i]
    print(df['imgname'][i])
    extracted_features = feat_extraction_model(img)
    #feat_size.append(extracted_features[18])
    #print(extracted_features[10])
    img_feat_array_last_layer[j] = extracted_features[-1]
    img_feat_array_last_layer[j+12114] = extracted_features[-1]
    #img_feat_array[j] = extracted_features
    #if i==10:
    #    break
    #i+=1
# Out:
# 0-s3gnQQLtpk-0.jpg
# 10-wleeOwxNxa-1.jpg
# 1002-mkJToFCz2W-2.jpg
# 1008-79ThFddYsp-1.jpg
# 1009-SpoauLdc9o-0.jpg
# 1011-Ai928js2rU-2.jpg
# 1013-eUUmwlxgrD-0.jpg
# 1016-tLtYznbfeR-0.jpg
# 1017-hEIKi3WKCO-1.jpg
# 1018-MjuGSB3rkh-2.jpg
# 1024-ocZ7d7YEtw-1.jpg
# 1028-Bqj3tvO2Zs-2.jpg
# 1029-KzmpVj2tqc-1.jpg
# 103-8lsQBwSWn7-1.jpg
# 1031-ShRKX52peS-0.jpg
# 1032-3wBAr3OgMo-0.jpg
# 1034-9EkOwDnSGj-2.jpg
# 1036-Hc6WgV5WEZ-1.jpg
# 1037-mXq2Sx9o6V-1.jpg
# 104-VpGuAFRV7b-2.jpg
# 1043-6UYAIvcTci-1.jpg
# 1044-vLw8h2kuxt-2.jpg
# 1045-HoRrU7DAbx-2.jpg
# 1046-Kubj262i5u-2.jpg
# 1048-G7trtFv6ux-1.jpg
# 105-UrTf6Cjzxp-2.jpg
# 1050-NKH66FEKWh-1.jpg
# 1051-THz5iUHQUz-2.jpg
# 1055-pHVmI93TVV-1.jpg
# 1058-kTFuGsDD9j-0.jpg
# 106-nfwkK5a3yJ-2.jpg
# 1063-dEUimzngGB-1.jpg
# 107-8ntifSyLu9-1.jpg
# 1070-zV2fPaqoEi-1.jpg
# 1071-UCXwC9ZLNl-2.jpg
# 1075-rLIBRAFHqM-2.jpg
# 1076-9KSNmx6MML-1.jpg
# 1077-vDJBOwdZrf-0.jpg
# 1078-E7EyuIsvrw-2.jpg
# 1079-QJIwdTBaXd-0.jpg
# 108-XYGTork3eg-0.jpg
# 1080-qWDNggeSUx-0.jpg
# ...

# %%
type(extracted_features[11])
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
#len(feat_size)

# %%
#feat_size[2]

# %%
#a = feat_size[0]

# %%
#np.save('features_0',feat_size)

# %%
#img_feat_array_last_layer

# %%
#np.shape(img_feat_array_last_layer[1])

# %%
#np.save('features_1',img_feat_array)

# %%
np.save('features_3_train',img_feat_array_last_layer)

# %%
#a = a.reshape(-1)
